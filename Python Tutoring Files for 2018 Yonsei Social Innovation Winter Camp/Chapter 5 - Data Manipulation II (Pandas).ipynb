# %% [markdown]
# # Chapter 5 - Data Manipulation II
#
# ## Pandas

# %% [markdown]
# Pandas is a python data analysis toolkit that provides fast, flexible and expressive data structures designed to make working with "relational" or "labeled" data in easy and intuitive way.
#
# Pandas have two primary data structures.
#
# - Series : 1-Dimensional
# - DataFrame: 2-Dimensional
#
# Pandas library is built on top of __Numpy__. (Which we learned in the previous chapter)
#
# The followings are examples of what pandas can do:
#
# - Handling missing data (NaN data)
# - Size mutability (Inserting and deleting columns or rows
# - Data alignment
# - Slicing and subsetting
# - Merging and Joining datasets
# - Reshaping data

# %% [markdown]
# ### Installation

# %% [markdown]
# For Mac users, _pip install pandas_ in your command prompt would work just fine.
#
# For Windows users, you should visit "https://www.lfd.uci.edu/~gohlke/pythonlibs/" and manually install the modules.
#
# 1. Assuming you have python 3.5 64bit on your computer follow the steps below
#   (changing "pandas‑0.22.0+mkl‑cp35‑cp35m‑win_amd64.whl" as appropriate).
#   (cp xx <- your python version   amd64 <- python bit version. 32 or 64 )
#
# 2. At the command prompt type following code:
#   __pip install pandas‑0.22.0+mkl‑cp35‑cp35m‑win_amd64.whl__

# %% [markdown]
# ### Import

# %%
# The most general way of importing pandas
import pandas as pd

# You can just do "import pandas" if you prefer this way

# %% [markdown]
# ### Exploring Pandas

# %%
# Executing this code will show documentation about pandas and how to use them
pd?

# %%
# Files, functions, modules, classes that pandas include
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Panel4D',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseList',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p15',
#  '_tslib',
#  '_version',
#  'api',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'datetime',
#  'datetools',
#  'describe_option',
#  'errors',
#  'eval',
#  'ewma',
#  'ewmcorr',
#  'ewmcov',
#  'ewmstd',
#  'ewmvar',
#  'ewmvol',
#  'expanding_apply',
#  'expanding_corr',
#  'expanding_count',
#  'expanding_cov',
#  'expanding_kurt',
#  'expanding_max',
#  'expanding_mean',
#  'expanding_median',
#  'expanding_min',
#  'expanding_quantile',
#  'expanding_skew',
#  'expanding_std',
#  'expanding_sum',
#  'expanding_var',
#  'factorize',
#  'get_dummies',
#  'get_option',
#  'get_store',
#  'groupby',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json',
#  'lib',
#  'lreshape',
#  'match',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'np',
#  'offsets',
#  'option_context',
#  'options',
#  'ordered_merge',
#  'pandas',
#  'parser',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plot_params',
#  'plotting',
#  'pnow',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_msgpack',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'reset_option',
#  'rolling_apply',
#  'rolling_corr',
#  'rolling_count',
#  'rolling_cov',
#  'rolling_kurt',
#  'rolling_max',
#  'rolling_mean',
#  'rolling_median',
#  'rolling_min',
#  'rolling_quantile',
#  'rolling_skew',
#  'rolling_std',
#  'rolling_sum',
#  'rolling_var',
#  'rolling_window',
#  'scatter_matrix',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'stats',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_msgpack',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tools',
#  'tseries',
#  'tslib',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %% [markdown]
# ### Basic Usage

# %% [markdown]
# As mentioned above, pandas is based on numpy. Let's try to remember what we have learned in the chapter 4

# %%
import numpy as np

data = np.array([["","column1","column2"],
                ["row1", 1, 2],
                ["row2", 3, 4]])

print(data)
type(data)
# Out:
# [['' 'column1' 'column2']
#  ['row1' '1' '2']
#  ['row2' '3' '4']]
# numpy.ndarray

# %% [markdown]
# As you can see in the output, variable __data__ is numpy array. The values of __data__ resemble somewhat resembles the shape of a table or matrix.
#
# Pandas comes in here.

# %% [markdown]
# ### pandas.Series

# %% [markdown]
# Why use pandas.Series??
#
# Python provides lists, dictionaries and tuples but why do we need to learn about the Series?
#
# Let's look at the exercise below

# %% [markdown]
# Exercise) _Try to save this table into a variable_
#
# | Date       | price|
# |:-----------|:-----|
# | 2018-01-01 | 9000 |
# | 2018-01-02 | 8000 |
# | 2018-01-03 | 7500 |
# | 2018-01-04 | 10000 |
# | 2018-01-05 | 5500 |

# %% [markdown]
# Using basic python data types and grammar, you would most likely to create a variable like this:

# %%
daily_ending_prices = {'2018-01-01': 9000,
                       '2018-01-02': 8000,
                       '2018-01-03': 7500,
                       '2018-01-04': 10000,
                       '2018-01-05': 5500}

print(daily_ending_prices)
# Out:
# {'2018-01-03': 7500, '2018-01-02': 8000, '2018-01-04': 10000, '2018-01-05': 5500, '2018-01-01': 9000}

# %% [markdown]
# Typing all these information one by one would have been very boring and most likely to make mistakes.
#
# Now, let's use pandas.Series
#
# pandas.Series is a class that takes two arguments: __data__ and __index__
#
#
#
# ex)
#     pandas.Series( data = _your_data_ , index = _your_index_ )
#
#
#
# In default, index is from 0 to len(_your_data_ - 1)

# %%
import pandas as pd

daily_end_price = pd.Series([9000,8000,7500,10000,5500])

print(daily_end_price)
# Out:
# 0     9000
# 1     8000
# 2     7500
# 3    10000
# 4     5500
# dtype: int64

# %% [markdown]
# pandas just did the alignment magically!! However, the dates are missing. Let's try this again

# %%
import pandas as pd

daily_end_price2 = pd.Series([9000,8000,7500,10000,5500],
                           index = ['2018-01-01','2018-01-02','2018-01-03','2018-01-04','2018-01-05']
                           )

print(daily_end_price2)
# Out:
# 2018-01-01     9000
# 2018-01-02     8000
# 2018-01-03     7500
# 2018-01-04    10000
# 2018-01-05     5500
# dtype: int64

# %% [markdown]
# Done. Beautifully.
#
# Pandas.Series is similar to the built-in data type Dictionary. It is a 1-Dimensional object similar to an array, list or column in a table. As mentioned above, values in Series are assigned with a labeled index, starting from 0 to N, where N is "length of Series - 1".  Of course, you can change the index numbers.
#
# The values of Series are Numpy array as you can see in the code below. This is because Pandas is built upon Numpy

# %%
daily_end_price2.values
# Out:
# array([ 9000,  8000,  7500, 10000,  5500])

# %% [markdown]
# You can also create Series with pre-defined dictionary

# %%
d = {'Chicago': 1000, 'New York': 1300, 'Portland': 900, 'San Francisco': 1100,
     'Austin': 450, 'Boston': None}

series = pd.Series(d)

series
# Out:
# Austin            450.0
# Boston              NaN
# Chicago          1000.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# dtype: float64

# %% [markdown]
# #### Changing Index number in Series

# %%
series1 = pd.Series(["Korea","Japan","China","United Kingdom","Canada","United States"], 
                    index = ["3","4","1","7","5","6"],
                    # index input should have same length with the data
                    name = "Country")
                    # name is used to call the name of series
series1
# Out:
# 3             Korea
# 4             Japan
# 1             China
# 7    United Kingdom
# 5            Canada
# 6     United States
# Name: Country, dtype: object

# %%
series2 = pd.Series(["Korea","Japan","China","United Kingdom","Canada","United States"], 
                    index = ["KR","JP","CH","UK","CA","US"],
                    # index input should have same length with the data
                    name = "Country")
                    # name is used to call the name of series
series2
# Out:
# KR             Korea
# JP             Japan
# CH             China
# UK    United Kingdom
# CA            Canada
# US     United States
# Name: Country, dtype: object

# %% [markdown]
# #### Manipulating Series

# %% [markdown]
# Let's bring the series that we created in the cells above

# %%
series
# Out:
# Austin            450.0
# Boston              NaN
# Chicago          1000.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# dtype: float64

# %% [markdown]
# #### Indexing

# %% [markdown]
# Specific elements in the Series can be called with index or boolean indexing just like lists or dictionaries

# %%
series["Chicago"]
# Out:
# 1000.0

# %%
series[["Chicago","Portland","New York"]]
# Out:
# Chicago     1000.0
# Portland     900.0
# New York    1300.0
# dtype: float64

# %%
print(series[series>1000])  # NA values are excluded from this filtering
print("\n")
print(series[series<=1000]) # NA values are excluded from this filtering
# Out:
# New York         1300.0
# San Francisco    1100.0
# dtype: float64
#
#
# Austin       450.0
# Chicago     1000.0
# Portland     900.0
# dtype: float64

# %% [markdown]
# We can also use dictionary like Python expressions and methods to examine the keys, indices and values

# %%
"Boston" in series
# Out:
# True

# %%
series.keys()
# Out:
# Index(['Austin', 'Boston', 'Chicago', 'New York', 'Portland', 'San Francisco'], dtype='object')

# %%
list(series.items())
# Out:
# [('Austin', 450.0),
#  ('Boston', nan),
#  ('Chicago', 1000.0),
#  ('New York', 1300.0),
#  ('Portland', 900.0),
#  ('San Francisco', 1100.0)]

# %% [markdown]
# There are methods like __loc , iloc__. Detailed description will be mentioned in the pandas.DataFrame part

# %%
series[2]
# Out:
# 1000.0

# %%
# Calling via index
print(series.loc["Austin"])
print("\n")
print(series1.loc["3"])
print("\n")
# Out:
# 450.0
#
#
# Korea

# %%
# Calling via number 
print(series.iloc[2])
print("\n")
print(series.iloc[1:4])
print("\n")
print(series.iloc[-3])
# Out:
# 1000.0
#
#
# Boston         NaN
# Chicago     1000.0
# New York    1300.0
# dtype: float64
#
#
# 1300.0

# %% [markdown]
# #### Mutation

# %%
series["Boston"] = 1300 # Re-assign the value from NA to 1300

series
# Out:
# Austin            450.0
# Boston           1300.0
# Chicago          1000.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# dtype: float64

# %% [markdown]
# #### Mathematical Operations with Series

# %%
series/3
# Out:
# Austin           150.000000
# Boston           433.333333
# Chicago          333.333333
# New York         433.333333
# Portland         300.000000
# San Francisco    366.666667
# dtype: float64

# %%
# Series and Series can be added together.
## Values on either Series that did not have a shared index will produce Null of NAN
series_copy = series/2

series_copy + series
# Out:
# Austin            675.0
# Boston           1950.0
# Chicago          1500.0
# New York         1950.0
# Portland         1350.0
# San Francisco    1650.0
# dtype: float64

# %% [markdown]
# #### Other Attributes

# %%
# is_unique
print(series1.is_unique)  # returns T/F if values in the object are unique

# shape
print(series1.shape) # returns a tuple of the shape of the underlying data

# size
print(series1.size) # returns the number of elements in the underlying data
# Out:
# True
# (6,)
# 6

# %% [markdown]
# ### pandas.DataFrame

# %% [markdown]
# A DataFrame is a tablular data structure comprised of rows and columns, akin to a spreadsheet, database table, or R's data.frame object. You can also think of a DataFrame as a group of Series objects that share an index (the column names).
#
# pandas.DataFrame is a class object, which enables 2-Dimensional table creation with the input variables.

# %%
# numpy array to DataFrame

information = pd.DataFrame(data = data[1:, 1:],  
                          index = data[1:, 0],  
                          columns = data[0,1:])

information
# Out:
#      column1 column2
# row1       1       2
# row2       3       4

# %% [markdown]
# Using pandas, we were able to convert data into a pretty table. This is the most basic usage of pandas.
#
# Numpy is not the only way to create a DataFrame

# %%
# Dictionary to DataFrame

Address = {"Name": ["Jaekeun","Dongkyu","Jeongwon","Sangjun"],
           "Height":["175","180","163","176"],
          "Age":["25","25","23","26"]}

df = pd.DataFrame(data= Address)

df
# Out:
#   Age Height      Name
# 0  25    175   Jaekeun
# 1  25    180   Dongkyu
# 2  23    163  Jeongwon
# 3  26    176   Sangjun

# %%
# Input data directly

df2 = pd.DataFrame( {"A": [1.,2.,3.,4.5,5,6.5],
                     "B": pd.Timestamp("2018-01-02"), #pandas.Timestamp is used for listing dates
                     "C": ["Y","N","N","N","Y","Y"],
                    })

df2
# Out:
#      A          B  C
# 0  1.0 2018-01-02  Y
# 1  2.0 2018-01-02  N
# 2  3.0 2018-01-02  N
# 3  4.5 2018-01-02  N
# 4  5.0 2018-01-02  Y
# 5  6.5 2018-01-02  Y

# %% [markdown]
# Each data columns should have the same number of elements

# %%
Idols = {"Twice": ["Jihyo","Nayeon","Jungyeon","Momo","Sana","Mina","Dahyun","Chaeyoung","Tzuyu"], 
           "Blackpink": ["Jisu","Jennie","Rose","Lisa"],
           "Bigbang": ["GD","TOP","Taeyang","Daesung","Seungri"],
           "BTS": ["RM","Suga","Jin","J-Hope","Jimin","V","Jungkook"]}

# %%
df = pd.DataFrame(data=Idols) # Does not work
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-e4a9dd600f98> in <module>()
# ----> 1 df = pd.DataFrame(data=Idols) # Does not work
#       2 df
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
#     463     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    6161     # figure out the index, if necessary
#    6162     if index is None:
# -> 6163         index = extract_index(arrays)
#    6164     else:
#    6165         index = _ensure_index(index)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in extract_index(data)
#    6209             lengths = list(set(raw_lengths))
#    6210             if len(lengths) > 1:
# -> 6211                 raise ValueError('arrays must all be same length')
#    6212
#    6213             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# This type of problem can be solved by implementing __Series__

# %%
# Convert lists into Series
Twice = pd.Series(["Jihyo","Nayeon","Jungyeon","Momo","Sana","Mina","Dahyun","Chaeyoung","Tzuyu"])
Blackpink = pd.Series(["Jisu","Jennie","Rose","Lisa"])
Bigbang = pd.Series(["GD","TOP","Taeyang","Daesung","Seungri"])
BTS = pd.Series(["RM","Suga","Jin","J-Hope","Jimin","V","Jungkook"])

# Form dictionary with the Series
Idol_Series = {"Twice":Twice,
               "Blackpink":Blackpink,
               "Bigbang": Bigbang,
               "BTS": BTS}

Idol = pd.DataFrame(Idol_Series)
Idol
# Out:
#         BTS  Bigbang Blackpink      Twice
# 0        RM       GD      Jisu      Jihyo
# 1      Suga      TOP    Jennie     Nayeon
# 2       Jin  Taeyang      Rose   Jungyeon
# 3    J-Hope  Daesung      Lisa       Momo
# 4     Jimin  Seungri       NaN       Sana
# 5         V      NaN       NaN       Mina
# 6  Jungkook      NaN       NaN     Dahyun
# 7       NaN      NaN       NaN  Chaeyoung
# 8       NaN      NaN       NaN      Tzuyu

# %% [markdown]
# Or, you can use loop to shorten the code

# %%
pd.DataFrame(dict([ (k, pd.Series(v)) for k,v in Idols.items()]))
# Out:
#         BTS  Bigbang Blackpink      Twice
# 0        RM       GD      Jisu      Jihyo
# 1      Suga      TOP    Jennie     Nayeon
# 2       Jin  Taeyang      Rose   Jungyeon
# 3    J-Hope  Daesung      Lisa       Momo
# 4     Jimin  Seungri       NaN       Sana
# 5         V      NaN       NaN       Mina
# 6  Jungkook      NaN       NaN     Dahyun
# 7       NaN      NaN       NaN  Chaeyoung
# 8       NaN      NaN       NaN      Tzuyu

# %% [markdown]
# #### Transpose

# %% [markdown]
# You can swap column and rows with T

# %%
Idol.T
# Out:
#                0       1         2        3        4     5         6  \
# BTS           RM    Suga       Jin   J-Hope    Jimin     V  Jungkook
# Bigbang       GD     TOP   Taeyang  Daesung  Seungri   NaN       NaN
# Blackpink   Jisu  Jennie      Rose     Lisa      NaN   NaN       NaN
# Twice      Jihyo  Nayeon  Jungyeon     Momo     Sana  Mina    Dahyun
#
#                    7      8
# BTS              NaN    NaN
# Bigbang          NaN    NaN
# Blackpink        NaN    NaN
# Twice      Chaeyoung  Tzuyu

# %% [markdown]
# #### Data Selection & Access

# %% [markdown]
# With pandas, you can select subset of data or access to specific values however you want.

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}

football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
football
# Out:
#    year     team  wins  losses
# 0  2010    Bears    11       5
# 1  2011    Bears     8       8
# 2  2012    Bears    10       6
# 3  2011  Packers    15       1
# 4  2012  Packers    11       5
# 5  2010    Lions     6      10
# 6  2011    Lions    10       6
# 7  2012    Lions     4      12

# %%
# Retrieve specific column
### Retrieve column "year"
print(football["year"])
print("\n")
print(football.year)
# Out:
# 0    2010
# 1    2011
# 2    2012
# 3    2011
# 4    2012
# 5    2010
# 6    2011
# 7    2012
# Name: year, dtype: int64
#
#
# 0    2010
# 1    2011
# 2    2012
# 3    2011
# 4    2012
# 5    2010
# 6    2011
# 7    2012
# Name: year, dtype: int64

# %% [markdown]
# __.loc__ is primarily label based, or can be used with boolean array. You may put list or array of index labels.

# %%
# Retrieve specific row 
## Remember! Python starts from "0"
### Retrieve rows from 0 to 4
print(football.loc[0:4])
print("\n")

# Retrieve rows that are only "True"
### Retrieve rows that have value 2012 in the "year" column
print(football.loc[football["year"]== 2012])
# Out:
#    year     team  wins  losses
# 0  2010    Bears    11       5
# 1  2011    Bears     8       8
# 2  2012    Bears    10       6
# 3  2011  Packers    15       1
# 4  2012  Packers    11       5
#
#
#    year     team  wins  losses
# 2  2012    Bears    10       6
# 4  2012  Packers    11       5
# 7  2012    Lions     4      12

# %% [markdown]
# __iloc__ is primarily integer position based, but it can also be used with boolean arrays.

# %%
# Retrieve value in specific position
### Retrieve  (row 1 and row 3) x (column 0 and column 2) 
print(football.iloc[[1,3],[0,2]])
print("\n")

### Retrieve (row 1 to row 4) x (column 1 to the end)
print(football.iloc[1:4,1:])
print("\n")


### Retrieve value in position of row2, column3
print(football.iloc[2,3])
# Out:
#    year  wins
# 1  2011     8
# 3  2011    15
#
#
#       team  wins  losses
# 1    Bears     8       8
# 2    Bears    10       6
# 3  Packers    15       1
#
#
# 6

# %% [markdown]
# __where()__ method is used to return rows that fit the condition in a Boolean way.
#
# It returns the whole dataset, but returns NaN for rows that do not fit its condition

# %%
football.where(football.wins >= 10)
# Out:
#      year     team  wins  losses
# 0  2010.0    Bears  11.0     5.0
# 1     NaN      NaN   NaN     NaN
# 2  2012.0    Bears  10.0     6.0
# 3  2011.0  Packers  15.0     1.0
# 4  2012.0  Packers  11.0     5.0
# 5     NaN      NaN   NaN     NaN
# 6  2011.0    Lions  10.0     6.0
# 7     NaN      NaN   NaN     NaN

# %% [markdown]
# You can also select random samples from your data

# %%
# Select random samples
### Retrieve random samples of size 1/3 of your original data
print(football.sample(frac= 1/3))
print("\n")
### Retrieve 3 random samples
print(football.sample(n=3))
# Out:
#    year     team  wins  losses
# 4  2012  Packers    11       5
# 3  2011  Packers    15       1
# 6  2011    Lions    10       6
#
#
#    year   team  wins  losses
# 7  2012  Lions     4      12
# 0  2010  Bears    11       5
# 2  2012  Bears    10       6

# %% [markdown]
# ### Data Import

# %% [markdown]
# Pandas makes reading data fairly easy. You can read data from a CSV file using read_csv function. They can be comma-seperated, tab-delimited.

# %% [markdown]
# _Pokemon Data_

# %% [markdown]
# The pokemon data includes 721 Pokemon, including their number, name, first and second type, basic stats: HP, Attack, Defense, Special Attack, Special Defense, and Speed. It can be downloaded from Kaggle, where you can find many other free datasets.
#
# As you can see, the data are __comma seperated__

# %% [markdown]
# ![Pokemon.csv.png](attachment:Pokemon.csv.png)

# %%
import pandas as pd

pokedata = pd.read_csv("/home/nowgeun/Desktop/Notebooks/Data/Pokemon.csv")

pokedata.head()  # the .head() function allows us to peek
                 # into the first part of the dataset
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# However, some data have different seperator or delimiter. For example, the data below, "Pokemon_sc.csv" seems to have semi-colon ";" as a delimiter.  In this case, you have to notify proper delimiter in the pandas.read_csv() function.

# %% [markdown]
# ![pokemon2.png](attachment:pokemon2.png)

# %%
pokedata2 = pd.read_csv("/home/nowgeun/Desktop/Notebooks/Data/Pokemon_sc.csv", 
                 delimiter=";")

pokedata2.tail() # .tail() function allows us to peek 
          # into the last part of the imported DataFrame
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# The data type of the imported data with pandas.read_csv() is __pandas.DataFrame__ you can check this with type() method

# %%
print(type(pokedata), type(pokedata2))
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Combining Datasets

# %% [markdown]
# #### Horizontal Output Display

# %%
class Display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
# Dataset 1

df1 = pd.DataFrame({
    'ID': [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    'Name': ['A', 'B', 'C', 'D', 'E', 'F', 'G']
}, columns=['ID', 'Name'])



# Dataset 2

df2 = pd.DataFrame({
    'ID': [1001, 1001, 1005, 1006, 1008, 1001],
    'Balance': [10000, 20000, 15000, 5000, 100000, 30000]
}, columns=['ID', 'Balance'])

print(df1)
print('\n')
print(df2)
# Out:
#      ID Name
# 0  1001    A
# 1  1002    B
# 2  1003    C
# 3  1004    D
# 4  1005    E
# 5  1006    F
# 6  1007    G
#
#
#      ID  Balance
# 0  1001    10000
# 1  1001    20000
# 2  1005    15000
# 3  1006     5000
# 4  1008   100000
# 5  1001    30000

# %% [markdown]
# ### pd.Merge

# %% [markdown]
# merge combines two DataFrames with common column or index. The standard column is named as __key__

# %% [markdown]
# ![Screenshot%20from%202018-01-10%2020-47-48.png](attachment:Screenshot%20from%202018-01-10%2020-47-48.png)

# %%
Left_join = pd.merge(df1,df2, how ="left")
Right_join = pd.merge(df1,df2, how ="right")
Outer_join = pd.merge(df1,df2, how ="outer")
Inner_join = pd.merge(df1,df2, how ="inner")

# %%
## Left Join
Display('df1', 'df2', 'Left_join')
# Out:
# df1
#      ID Name
# 0  1001    A
# 1  1002    B
# 2  1003    C
# 3  1004    D
# 4  1005    E
# 5  1006    F
# 6  1007    G
#
# df2
#      ID  Balance
# 0  1001    10000
# 1  1001    20000
# 2  1005    15000
# 3  1006     5000
# 4  1008   100000
# 5  1001    30000
#
# Left_join
#      ID Name  Balance
# 0  1001    A  10000.0
# 1  1001    A  20000.0
# 2  1001    A  30000.0
# 3  1002    B      NaN
# 4  1003    C      NaN
# 5  1004    D      NaN
# 6  1005    E  15000.0
# 7  1006    F   5000.0
# 8  1007    G      NaN

# %%
## Right Join
Display('df1','df2','Right_join')
# Out:
# df1
#      ID Name
# 0  1001    A
# 1  1002    B
# 2  1003    C
# 3  1004    D
# 4  1005    E
# 5  1006    F
# 6  1007    G
#
# df2
#      ID  Balance
# 0  1001    10000
# 1  1001    20000
# 2  1005    15000
# 3  1006     5000
# 4  1008   100000
# 5  1001    30000
#
# Right_join
#      ID Name  Balance
# 0  1001    A    10000
# 1  1001    A    20000
# 2  1001    A    30000
# 3  1005    E    15000
# 4  1006    F     5000
# 5  1008  NaN   100000

# %%
## Outer Join
Display('df1','df2','Outer_join')
# Out:
# df1
#      ID Name
# 0  1001    A
# 1  1002    B
# 2  1003    C
# 3  1004    D
# 4  1005    E
# 5  1006    F
# 6  1007    G
#
# df2
#      ID  Balance
# 0  1001    10000
# 1  1001    20000
# 2  1005    15000
# 3  1006     5000
# 4  1008   100000
# 5  1001    30000
#
# Outer_join
#      ID Name   Balance
# 0  1001    A   10000.0
# 1  1001    A   20000.0
# 2  1001    A   30000.0
# 3  1002    B       NaN
# 4  1003    C       NaN
# 5  1004    D       NaN
# 6  1005    E   15000.0
# 7  1006    F    5000.0
# 8  1007    G       NaN
# 9  1008  NaN  100000.0

# %%
## Inner Join
Display('df1','df2','Inner_join')
# Out:
# df1
#      ID Name
# 0  1001    A
# 1  1002    B
# 2  1003    C
# 3  1004    D
# 4  1005    E
# 5  1006    F
# 6  1007    G
#
# df2
#      ID  Balance
# 0  1001    10000
# 1  1001    20000
# 2  1005    15000
# 3  1006     5000
# 4  1008   100000
# 5  1001    30000
#
# Inner_join
#      ID Name  Balance
# 0  1001    A    10000
# 1  1001    A    20000
# 2  1001    A    30000
# 3  1005    E    15000
# 4  1006    F     5000

# %% [markdown]
# ### pd.concat

# %% [markdown]
# concat just concatenate the two dataframes. Because of this, index numbers may be repeated.

# %% [markdown]
# #### Joining two DataFrames along rows

# %%
df_row = pd.concat([df1, df2])
df_row
# Out:
#     Balance    ID Name
# 0       NaN  1001    A
# 1       NaN  1002    B
# 2       NaN  1003    C
# 3       NaN  1004    D
# 4       NaN  1005    E
# 5       NaN  1006    F
# 6       NaN  1007    G
# 0   10000.0  1001  NaN
# 1   20000.0  1001  NaN
# 2   15000.0  1005  NaN
# 3    5000.0  1006  NaN
# 4  100000.0  1008  NaN
# 5   30000.0  1001  NaN

# %% [markdown]
# #### Joning two DataFrames along columns

# %%
df_col = pd.concat([df1, df2], axis=1)
df_col
# Out:
#      ID Name      ID   Balance
# 0  1001    A  1001.0   10000.0
# 1  1002    B  1001.0   20000.0
# 2  1003    C  1005.0   15000.0
# 3  1004    D  1006.0    5000.0
# 4  1005    E  1008.0  100000.0
# 5  1006    F  1001.0   30000.0
# 6  1007    G     NaN       NaN

# %% [markdown]
# ### Handling Missing Data

# %% [markdown]
# The difference between data found in many tutorials and data in the real world is that real-world data is rarely clean and homogeneous. In particular, many interesting datasets will have some amount of data missing. To make matters even more complicated, different data sources may indicate missing data in different ways.
#
# In this section, we will discuss some general considerations for missing data, discuss how Pandas chooses to represent it, and demonstrate some built-in Pandas tools for handling missing data in Python. From now on, we'll refer to missing data in general as null, NaN, or NA values.

# %% [markdown]
# In python, missing values are represented as __None__.
#
# In Pandas or Numpy, __NaN__ represents "missing numerical data".
# It is a recognized as a special floating-point.

# %%
group1 = np.array([1,2,3,4,None])
group2 = np.array([1,2,3,4, np.nan]) #np.nan is used to generate NaN on purpose

print(group1.dtype, group2.dtype) 

# As you can see, np.nan is recognized as a float 
# while None is recognized as an object
# Out:
# object float64

# %% [markdown]
# However, NaN will raise problem when doing calculation

# %%
print(1 + np.nan)
print(0 * np.nan)
print(group2.sum())
# Out:
# nan
# nan
# nan

# %% [markdown]
# To solve this problem, Numpy provides some special functions that ignore these missing values:

# %%
np.nansum(group2)
# Out:
# 10.0

# %% [markdown]
# There are 4 methods used to handle these missing values:
#
# - isnull() : Generate a boolean mask indicating missing values
# - notnull() : Opposite of isnull()
# - dropna() : Return a filtered version of the data
# - fillna() : Return a copy of the data with missing values filled

# %%
data = pd.Series([1, np.nan, "hello", None])

# %%
# Detecting Null Values

data.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data[data.notnull()]
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
# Dropping null values

data.dropna()
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
df = pd.DataFrame([[0,1,2,3,4,np.nan],
                  [1,2, np.nan, 4,6,7],
                  [1,3,6,8,4,4],
                  [4,np.nan,np.nan,np.nan,np.nan,np.nan],
                  [5,4,3,6,8,9]])

df
# Out:
#    0    1    2    3    4    5
# 0  0  1.0  2.0  3.0  4.0  NaN
# 1  1  2.0  NaN  4.0  6.0  7.0
# 2  1  3.0  6.0  8.0  4.0  4.0
# 3  4  NaN  NaN  NaN  NaN  NaN
# 4  5  4.0  3.0  6.0  8.0  9.0

# %%
df.dropna() # Drops all rows which includes any null value
# Out:
#    0    1    2    3    4    5
# 2  1  3.0  6.0  8.0  4.0  4.0
# 4  5  4.0  3.0  6.0  8.0  9.0

# %%
df.dropna(axis=1) # Drops all columns containing a null value
# Out:
#    0
# 0  0
# 1  1
# 2  1
# 3  4
# 4  5

# %%
df.iloc[:,1:]
# Out:
#      1    2    3    4    5
# 0  1.0  2.0  3.0  4.0  NaN
# 1  2.0  NaN  4.0  6.0  7.0
# 2  3.0  6.0  8.0  4.0  4.0
# 3  NaN  NaN  NaN  NaN  NaN
# 4  4.0  3.0  6.0  8.0  9.0

# %%
df.iloc[:,1:].dropna(axis='rows', how='all')
# drops rows only if all the values are nan
# row 3 will be gone.
# Out:
#      1    2    3    4    5
# 0  1.0  2.0  3.0  4.0  NaN
# 1  2.0  NaN  4.0  6.0  7.0
# 2  3.0  6.0  8.0  4.0  4.0
# 4  4.0  3.0  6.0  8.0  9.0

# %%
# Filling in Null Values
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
data.fillna(0)
# Out:
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64

# %%
# Forward fill: propagate the previous value forward
data.fillna(method='ffill')
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %%
# back-fill: propagate the next values backward
data.fillna(method='bfill')
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %% [markdown]
# ### Aggregation and Grouping

# %% [markdown]
# An essential piece of analysis of large data is efficient summarization: computing aggregations like sum(), mean(), median(), min(), and max(), in which a single number gives insight into the nature of a potentially large dataset. In this section, we'll explore aggregations in Pandas, from simple operations akin to what we've seen on NumPy arrays, to more sophisticated operations based on the concept of a groupby.

# %%
import seaborn as sns
planets = sns.load_dataset('planets')
planets.shape
# Out:
# (1035, 6)

# %%
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# #### Simple Aggregation

# %%
# Series 

rng = np.random.RandomState(42)
ser = pd.Series(rng.rand(5))
ser
# Out:
# 0    0.374540
# 1    0.950714
# 2    0.731994
# 3    0.598658
# 4    0.156019
# dtype: float64

# %%
ser.sum()
# Out:
# 2.8119254917081569

# %%
ser.mean()
# Out:
# 0.56238509834163142

# %%
ser.std()
# Out:
# 0.30874824961862174

# %%
# DataFrame

df = pd.DataFrame({'A': rng.rand(5),
                   'B': rng.rand(5)})
df
# Out:
#           A         B
# 0  0.155995  0.020584
# 1  0.058084  0.969910
# 2  0.866176  0.832443
# 3  0.601115  0.212339
# 4  0.708073  0.181825

# %%
df.sum()
# Out:
# A    2.389442
# B    2.217101
# dtype: float64

# %%
df.mean()
# Out:
# A    0.477888
# B    0.443420
# dtype: float64

# %%
df.mean(axis=1) # Aggregation with in each row
# Out:
# 0    0.088290
# 1    0.513997
# 2    0.849309
# 3    0.406727
# 4    0.444949
# dtype: float64

# %%
df.std()
# Out:
# A    0.353125
# B    0.426952
# dtype: float64

# %% [markdown]
# #### Groupby: Split, Apply, Combine
#
# Simple aggregations can give you a flavor of your dataset, but often we would prefer to aggregate conditionally on some label or index: this is implemented in the so-called groupby operation. The name "group by" comes from a command in the SQL database language, but it is perhaps more illuminative to think of it in the terms first coined by Hadley Wickham of Rstats fame: split, apply, combine.

# %% [markdown]
# ![groupby_sac.png](attachment:groupby_sac.png)

# %% [markdown]
# - The __split__ step involves breaking up and grouping a DataFrame depending on the value of the specified key.
# - The __apply__ step involves computing some function, usually an aggregate, transformation, or filtering, within the individual groups.
# - The __combine__ step merges the results of these operations into an output array.

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data': range(6)}, columns=['key', 'data'])
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %%
df.groupby('key')

# %%
df.groupby('key').sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7

# %% [markdown]
# #### Aggregate, Filter, Transform, Apply

# %% [markdown]
# Let's use our Pokemon data

# %%
pokedata.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# __aggregate()__ method allows flexible application of diverse functions. It can take a string, a function, or a list and compute all the aggregates at once.

# %%
# Let's organize all the pokemon's statistical stats by their type 1
pokedata.groupby("Type 1").aggregate(["min", np.mean, max])
# Out:
#             #                  Total                   HP                  \
#           min        mean  max   min        mean  max min       mean  max
# Type 1
# Bug        10  334.492754  666   194  378.927536  600   1  56.884058   86
# Dark      197  461.354839  717   220  445.741935  680  35  66.806452  126
# Dragon    147  474.375000  718   300  550.531250  780  41  83.312500  125
# Electric   25  363.500000  702   205  443.409091  610  20  59.795455   90
# Fairy      35  449.529412  716   218  413.176471  680  35  74.117647  126
# Fighting   56  363.851852  701   210  416.444444  625  30  69.851852  144
# Fire        4  327.403846  721   250  458.076923  680  38  69.903846  115
# Flying    641  677.750000  715   245  485.000000  580  40  70.750000   85
# Ghost      92  486.500000  711   275  439.562500  680  20  64.437500  150
# Grass       1  344.871429  673   180  421.142857  630  30  67.271429  123
# Ground     27  356.281250  645   265  437.500000  770  10  73.781250  115
# Ice       124  423.541667  713   250  433.458333  580  36  72.000000  110
# Normal     16  319.173469  676   190  401.683673  720  30  77.275510  255
# Poison     23  251.785714  691   245  399.142857  535  35  67.250000  105
# Psychic    63  380.807018  720   198  475.947368  780  20  70.631579  190
# Rock       74  392.727273  719   280  453.750000  700  30  65.363636  123
# Steel     208  442.851852  707   300  487.703704  700  40  65.222222  100
# Water       7  303.089286  693   200  430.455357  770  20  72.062500  170
#
#          Attack  ...   Sp. Def Speed                  Generation            \
#             min  ...       max   min        mean  max        min      mean
# Type 1           ...
# Bug          10  ...       230     5   61.681159  160          1  3.217391
# Dark         50  ...       130    20   76.161290  125          2  4.032258
# Dragon       50  ...       150    40   83.031250  120          1  3.875000
# Electric     30  ...       110    35   84.500000  140          1  3.272727
# Fairy        20  ...       154    15   48.588235   99          1  4.117647
# Fighting     35  ...       110    25   66.074074  118          1  3.370370
# Fire         30  ...       154    20   74.442308  126          1  3.211538
# Flying       30  ...        90    55  102.500000  123          5  5.500000
# Ghost        30  ...       135    20   64.343750  130          1  4.187500
# Grass        27  ...       129    10   61.928571  145          1  3.357143
# Ground       40  ...       120    10   63.906250  120          1  3.156250
# Ice          30  ...       200    25   63.458333  110          1  3.541667
# Normal        5  ...       135     5   71.551020  135          1  3.051020
# Poison       43  ...       123    25   63.571429  130          1  2.535714
# Psychic      20  ...       160    20   81.491228  180          1  3.385965
# Rock         40  ...       150    10   55.909091  150          1  3.454545
# Steel        24  ...       150    23   55.259259  110          2  3.851852
# Water        10  ...       160    15   65.964286  122          1  2.857143
#
#              Legendary
#          max       min      mean    max
# Type 1
# Bug        6     False  0.000000  False
# Dark       6     False  0.064516   True
# Dragon     6     False  0.375000   True
# Electric   6     False  0.090909   True
# Fairy      6     False  0.058824   True
# Fighting   6     False  0.000000  False
# Fire       6     False  0.096154   True
# Flying     6     False  0.500000   True
# Ghost      6     False  0.062500   True
# Grass      6     False  0.042857   True
# Ground     5     False  0.125000   True
# Ice        6     False  0.083333   True
# Normal     6     False  0.020408   True
# Poison     6     False  0.000000  False
# Psychic    6     False  0.245614   True
# Rock       6     False  0.090909   True
# Steel      6     False  0.148148   True
# Water      6     False  0.035714   True
#
# [18 rows x 30 columns]

# %%
pokedata.groupby("Type 1").aggregate({"HP": "mean",
                                      "Attack": "max"})
# Out:
#           Attack         HP
# Type 1
# Bug          185  56.884058
# Dark         150  66.806452
# Dragon       180  83.312500
# Electric     123  59.795455
# Fairy        131  74.117647
# Fighting     145  69.851852
# Fire         160  69.903846
# Flying       115  70.750000
# Ghost        165  64.437500
# Grass        132  67.271429
# Ground       180  73.781250
# Ice          130  72.000000
# Normal       160  77.275510
# Poison       106  67.250000
# Psychic      190  70.631579
# Rock         165  65.363636
# Steel        150  65.222222
# Water        155  72.062500

# %% [markdown]
# __filter()__ method allows you to drop data based on the group properties. We might want to keep all groups in which the mean is greater than some critical value

# %%
def highHP(x):
    return x["HP"].mean() > 73

# %%
pokedata.groupby("Type 1").filter(highHP)
# Out:
#        #                       Name  Type 1    Type 2  Total   HP  Attack  \
# 20    16                     Pidgey  Normal    Flying    251   40      45
# 21    17                  Pidgeotto  Normal    Flying    349   63      60
# 22    18                    Pidgeot  Normal    Flying    479   83      80
# 23    18        PidgeotMega Pidgeot  Normal    Flying    579   83      80
# 24    19                    Rattata  Normal       NaN    253   30      56
# 25    20                   Raticate  Normal       NaN    413   55      81
# 26    21                    Spearow  Normal    Flying    262   40      60
# 27    22                     Fearow  Normal    Flying    442   65      90
# 32    27                  Sandshrew  Ground       NaN    300   50      75
# 33    28                  Sandslash  Ground       NaN    450   75     100
# 40    35                   Clefairy   Fairy       NaN    323   70      45
# 41    36                   Clefable   Fairy       NaN    483   95      70
# 44    39                 Jigglypuff  Normal     Fairy    270  115      45
# 45    40                 Wigglytuff  Normal     Fairy    435  140      70
# 55    50                    Diglett  Ground       NaN    265   10      55
# 56    51                    Dugtrio  Ground       NaN    405   35      80
# 57    52                     Meowth  Normal       NaN    290   40      45
# 58    53                    Persian  Normal       NaN    440   65      70
# 90    83                 Farfetch'd  Normal    Flying    352   52      65
# 91    84                      Doduo  Normal    Flying    310   35      85
# 92    85                     Dodrio  Normal    Flying    460   60     110
# 112  104                     Cubone  Ground       NaN    320   50      50
# 113  105                    Marowak  Ground       NaN    425   60      80
# 116  108                  Lickitung  Normal       NaN    385   90      55
# 119  111                    Rhyhorn  Ground      Rock    345   80      85
# 120  112                     Rhydon  Ground      Rock    485  105     130
# 121  113                    Chansey  Normal       NaN    450  250       5
# 123  115                 Kangaskhan  Normal       NaN    490  105      95
# 124  115  KangaskhanMega Kangaskhan  Normal       NaN    590  105     125
# 138  128                     Tauros  Normal       NaN    490   75     100
# ..   ...                        ...     ...       ...    ...  ...     ...
# 684  623                     Golurk  Ground     Ghost    483   89     124
# 687  626                 Bouffalant  Normal       NaN    490   95     110
# 688  627                    Rufflet  Normal    Flying    350   70      83
# 689  628                   Braviary  Normal    Flying    510  100     123
# 706  643                   Reshiram  Dragon      Fire    680  100     120
# 707  644                     Zekrom  Dragon  Electric    680  100     150
# 708  645    LandorusIncarnate Forme  Ground    Flying    600   89     125
# 709  645      LandorusTherian Forme  Ground    Flying    600   89     145
# 710  646                     Kyurem  Dragon       Ice    660  125     130
# 711  646         KyuremBlack Kyurem  Dragon       Ice    700  125     170
# 712  646         KyuremWhite Kyurem  Dragon       Ice    700  125     120
# 715  648         MeloettaAria Forme  Normal   Psychic    600  100      77
# 716  648    MeloettaPirouette Forme  Normal  Fighting    600  100     128
# 727  659                   Bunnelby  Normal       NaN    237   38      36
# 728  660                  Diggersby  Normal    Ground    423   85      56
# 729  661                 Fletchling  Normal    Flying    278   45      50
# 737  669                    Flabébé   Fairy       NaN    303   44      38
# 738  670                    Floette   Fairy       NaN    371   54      45
# 739  671                    Florges   Fairy       NaN    552   78      65
# 744  676                    Furfrou  Normal       NaN    472   75      80
# 752  682                   Spritzee   Fairy       NaN    341   78      52
# 753  683                 Aromatisse   Fairy       NaN    462  101      72
# 754  684                    Swirlix   Fairy       NaN    341   62      48
# 755  685                   Slurpuff   Fairy       NaN    480   82      80
# 770  700                    Sylveon   Fairy       NaN    525   95      65
# 774  704                      Goomy  Dragon       NaN    300   45      50
# 775  705                    Sliggoo  Dragon       NaN    452   68      75
# 776  706                     Goodra  Dragon       NaN    600   90     100
# 792  716                    Xerneas   Fairy       NaN    680  126     131
# 794  718           Zygarde50% Forme  Dragon    Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20        40       35       35     56           1      False
# 21        55       50       50     71           1      False
# 22        75       70       70    101           1      False
# 23        80      135       80    121           1      False
# 24        35       25       35     72           1      False
# 25        60       50       70     97           1      False
# 26        30       31       31     70           1      False
# 27        65       61       61    100           1      False
# 32        85       20       30     40           1      False
# 33       110       45       55     65           1      False
# 40        48       60       65     35           1      False
# 41        73       95       90     60           1      False
# 44        20       45       25     20           1      False
# 45        45       85       50     45           1      False
# 55        25       35       45     95           1      False
# 56        50       50       70    120           1      False
# 57        35       40       40     90           1      False
# 58        60       65       65    115           1      False
# 90        55       58       62     60           1      False
# 91        45       35       35     75           1      False
# 92        70       60       60    100           1      False
# 112       95       40       50     35           1      False
# 113      110       50       80     45           1      False
# 116       75       60       75     30           1      False
# 119       95       30       30     25           1      False
# 120      120       45       45     40           1      False
# 121        5       35      105     50           1      False
# 123       80       40       80     90           1      False
# 124      100       60      100    100           1      False
# 138       95       40       70    110           1      False
# ..       ...      ...      ...    ...         ...        ...
# 684       80       55       80     55           5      False
# 687       95       40       95     55           5      False
# 688       50       37       50     60           5      False
# 689       75       57       75     80           5      False
# 706      100      150      120     90           5       True
# 707      120      120      100     90           5       True
# 708       90      115       80    101           5       True
# 709       90      105       80     91           5       True
# 710       90      130       90     95           5       True
# 711      100      120       90     95           5       True
# 712       90      170      100     95           5       True
# 715       77      128      128     90           5      False
# 716       90       77       77    128           5      False
# 727       38       32       36     57           6      False
# 728       77       50       77     78           6      False
# 729       43       40       38     62           6      False
# 737       39       61       79     42           6      False
# 738       47       75       98     52           6      False
# 739       68      112      154     75           6      False
# 744       60       65       90    102           6      False
# 752       60       63       65     23           6      False
# 753       72       99       89     29           6      False
# 754       66       59       57     49           6      False
# 755       86       85       75     72           6      False
# 770       65      110      130     60           6      False
# 774       35       55       75     40           6      False
# 775       53       83      113     60           6      False
# 776       70      110      150     80           6      False
# 792       95      131       98     99           6       True
# 794      121       81       95     95           6       True
#
# [179 rows x 13 columns]

# %% [markdown]
# All the other pokemons excluding Fairy, Normal, Ground, Dragon types have been dropped because their types have mean HP less than 73

# %% [markdown]
# __transform()__ returns transformed version of the full data for recombination. The output is same shape as input.

# %%
pokedata.groupby("Type 1").transform(lambda x: x - x.mean()).head()
# Out:
#             #       Total         HP     Attack    Defense    Sp. Atk  \
# 0 -343.871429 -103.142857 -22.271429 -24.214286 -21.800000 -12.500000
# 1 -342.871429  -16.142857  -7.271429 -11.214286  -7.800000   2.500000
# 2 -341.871429  103.857143  12.728571   8.785714  12.200000  22.500000
# 3 -341.871429  203.857143  12.728571  26.785714  52.200000  44.500000
# 4 -323.403846 -149.076923 -30.903846 -32.769231 -24.769231 -28.980769
#
#      Sp. Def      Speed  Generation  Legendary
# 0  -5.428571 -16.928571   -2.357143  -0.042857
# 1   9.571429  -1.928571   -2.357143  -0.042857
# 2  29.571429  18.071429   -2.357143  -0.042857
# 3  49.571429  18.071429   -2.357143  -0.042857
# 4 -22.211538  -9.442308   -2.211538  -0.096154

# %% [markdown]
# __apply()__ method allows application of an arbitrary function to the group results. The function should take a DataFrame and return either a Pandas object or a scalar; the combine operation will be tailored to the type of output returned.

# %%
pokedata.groupby("Type 1").apply(lambda x: x.describe())
# Out:
#                          #       Total          HP      Attack     Defense  \
# Type 1
# Bug      count   69.000000   69.000000   69.000000   69.000000   69.000000
#          mean   334.492754  378.927536   56.884058   70.971014   70.724638
#          std    210.445160  117.875223   16.328914   37.040904   33.617609
#          min     10.000000  194.000000    1.000000   10.000000   30.000000
#          25%    168.000000  269.000000   45.000000   45.000000   50.000000
#          50%    291.000000  395.000000   60.000000   65.000000   60.000000
#          75%    543.000000  475.000000   70.000000   90.000000   90.000000
#          max    666.000000  600.000000   86.000000  185.000000  230.000000
# Dark     count   31.000000   31.000000   31.000000   31.000000   31.000000
#          mean   461.354839  445.741935   66.806452   88.387097   70.225806
#          std    176.022072  109.126217   21.078297   25.774247   25.121982
#          min    197.000000  220.000000   35.000000   50.000000   30.000000
#          25%    282.000000  359.000000   51.000000   65.000000   51.000000
#          50%    509.000000  465.000000   65.000000   88.000000   70.000000
#          75%    627.000000  510.000000   73.500000  100.000000   90.000000
#          max    717.000000  680.000000  126.000000  150.000000  125.000000
# Dragon   count   32.000000   32.000000   32.000000   32.000000   32.000000
#          mean   474.375000  550.531250   83.312500  112.125000   86.375000
#          std    170.190169  146.267538   23.795415   33.742622   24.102938
#          min    147.000000  300.000000   41.000000   50.000000   35.000000
#          25%    373.000000  420.000000   67.500000   86.250000   68.750000
#          50%    443.500000  600.000000   80.000000  113.500000   90.000000
#          75%    643.250000  680.000000  101.250000  134.250000  100.000000
#          max    718.000000  780.000000  125.000000  180.000000  130.000000
# Electric count   44.000000   44.000000   44.000000   44.000000   44.000000
#          mean   363.500000  443.409091   59.795455   69.090909   66.295455
#          std    202.731063  105.721952   17.306511   23.764169   24.757033
#          min     25.000000  205.000000   20.000000   30.000000   15.000000
#          25%    179.750000  362.250000   50.000000   53.750000   49.750000
#          50%    403.500000  477.500000   60.000000   65.000000   65.000000
# ...                    ...         ...         ...         ...         ...
# Psychic  std    194.600455  139.026645   28.421340   42.309265   28.359401
#          min     63.000000  198.000000   20.000000   20.000000   15.000000
#          25%    201.000000  336.000000   50.000000   45.000000   48.000000
#          50%    386.000000  485.000000   68.000000   57.000000   65.000000
#          75%    528.000000  600.000000   80.000000   95.000000   80.000000
#          max    720.000000  780.000000  190.000000  190.000000  160.000000
# Rock     count   44.000000   44.000000   44.000000   44.000000   44.000000
#          mean   392.727273  453.750000   65.363636   92.863636  100.795455
#          std    213.746140  108.059227   20.833884   35.325458   36.447209
#          min     74.000000  280.000000   30.000000   40.000000   40.000000
#          25%    230.750000  360.250000   50.000000   59.750000   71.500000
#          50%    362.500000  467.500000   68.500000   95.000000  100.000000
#          75%    566.250000  516.500000   80.000000  120.250000  120.500000
#          max    719.000000  700.000000  123.000000  165.000000  200.000000
# Steel    count   27.000000   27.000000   27.000000   27.000000   27.000000
#          mean   442.851852  487.703704   65.222222   92.703704  126.370370
#          std    164.847180  115.420907   16.044010   30.388276   44.806548
#          min    208.000000  300.000000   40.000000   24.000000   50.000000
#          25%    305.500000  425.000000   57.000000   77.500000   97.500000
#          50%    379.000000  500.000000   60.000000   89.000000  120.000000
#          75%    600.500000  580.000000   75.000000  110.000000  150.000000
#          max    707.000000  700.000000  100.000000  150.000000  230.000000
# Water    count  112.000000  112.000000  112.000000  112.000000  112.000000
#          mean   303.089286  430.455357   72.062500   74.151786   72.946429
#          std    188.440807  113.188266   27.487026   28.377192   27.773809
#          min      7.000000  200.000000   20.000000   10.000000   20.000000
#          25%    130.000000  328.750000   52.250000   53.000000   54.500000
#          50%    275.000000  455.000000   70.000000   72.000000   70.000000
#          75%    456.250000  502.250000   90.250000   92.000000   88.500000
#          max    693.000000  770.000000  170.000000  155.000000  180.000000
#
#                    Sp. Atk     Sp. Def       Speed  Generation
# Type 1
# Bug      count   69.000000   69.000000   69.000000   69.000000
#          mean    53.869565   64.797101   61.681159    3.217391
#          std     26.697055   32.126395   33.227599    1.598433
#          min     10.000000   20.000000    5.000000    1.000000
#          25%     35.000000   45.000000   36.000000    2.000000
#          50%     50.000000   60.000000   60.000000    3.000000
#          75%     65.000000   80.000000   85.000000    5.000000
#          max    135.000000  230.000000  160.000000    6.000000
# Dark     count   31.000000   31.000000   31.000000   31.000000
#          mean    74.645161   69.516129   76.161290    4.032258
#          std     33.200952   24.799020   27.768203    1.353609
#          min     30.000000   30.000000   20.000000    2.000000
#          25%     45.000000   50.000000   59.000000    3.000000
#          50%     65.000000   65.000000   70.000000    5.000000
#          75%     96.500000   87.500000   98.500000    5.000000
#          max    140.000000  130.000000  125.000000    6.000000
# Dragon   count   32.000000   32.000000   32.000000   32.000000
#          mean    96.843750   88.843750   83.031250    3.875000
#          std     42.257360   29.884843   23.239961    1.431219
#          min     30.000000   30.000000   40.000000    1.000000
#          25%     60.000000   70.000000   65.250000    3.000000
#          50%    105.000000   90.000000   90.000000    4.000000
#          75%    122.500000  105.000000   97.750000    5.000000
#          max    180.000000  150.000000  120.000000    6.000000
# Electric count   44.000000   44.000000   44.000000   44.000000
#          mean    90.022727   73.704545   84.500000    3.272727
#          std     29.740340   22.601275   26.691607    1.604697
#          min     35.000000   32.000000   35.000000    1.000000
#          25%     65.000000   55.000000   60.000000    2.000000
#          50%     95.000000   79.500000   88.000000    4.000000
# ...                    ...         ...         ...         ...
# Psychic  std     38.539340   31.126329   37.335412    1.644845
#          min     23.000000   20.000000   20.000000    1.000000
#          25%     70.000000   58.000000   50.000000    2.000000
#          50%     95.000000   90.000000   80.000000    3.000000
#          75%    125.000000  110.000000  104.000000    5.000000
#          max    194.000000  160.000000  180.000000    6.000000
# Rock     count   44.000000   44.000000   44.000000   44.000000
#          mean    63.340909   75.477273   55.909091    3.454545
#          std     28.249670   32.265965   29.903580    1.848375
#          min     10.000000   25.000000   10.000000    1.000000
#          25%     45.000000   50.000000   35.000000    2.000000
#          50%     60.000000   70.000000   50.000000    3.000000
#          75%     74.250000   90.500000   70.000000    5.000000
#          max    160.000000  150.000000  150.000000    6.000000
# Steel    count   27.000000   27.000000   27.000000   27.000000
#          mean    67.518519   80.629630   55.259259    3.851852
#          std     31.458606   29.018758   25.846578    1.350319
#          min     24.000000   37.000000   23.000000    2.000000
#          25%     47.500000   60.000000   31.500000    3.000000
#          50%     55.000000   80.000000   50.000000    3.000000
#          75%     79.500000   95.000000   70.000000    5.000000
#          max    150.000000  150.000000  110.000000    6.000000
# Water    count  112.000000  112.000000  112.000000  112.000000
#          mean    74.812500   70.517857   65.964286    2.857143
#          std     29.030128   28.460493   23.019353    1.558800
#          min     10.000000   20.000000   15.000000    1.000000
#          25%     55.000000   50.000000   50.000000    1.000000
#          50%     70.000000   65.000000   65.000000    3.000000
#          75%     90.500000   89.250000   82.000000    4.000000
#          max    180.000000  160.000000  122.000000    6.000000
#
# [144 rows x 9 columns]

# %% [markdown]
# ### Pivot Table

# %% [markdown]
# DataFrame has __pivot_table__ method enabling creation of pivot table

# %% [markdown]
# Data visualization package seaborn provides some dataset.
# Titanic dataset is provided.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# You can manually create a pivot table using indexing and calling columns selectively.

titanic.groupby('sex')[['survived']].mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
# using pivot_table() method

titanic.pivot_table("survived", index="sex")
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %% [markdown]
# __pivot table with more columns__

# %%
titanic.pivot_table('survived', index="sex", columns ="class")
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# __multi level pivot tables__

# %%
# cut by age
age = pd.cut(titanic['age'], [0, 18, 80])
titanic.pivot_table('survived', ['sex', age], 'class')
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 80]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 80]  0.375000  0.071429  0.133663

# %%
# cut by age and fare 
fare = pd.qcut(titanic['fare'], 2)
titanic.pivot_table('survived', ['sex', age], [fare, 'class'])
# Out:
# fare            (-0.001, 14.454]                     (14.454, 512.329]  \
# class                      First    Second     Third             First
# sex    age
# female (0, 18]               NaN  1.000000  0.714286          0.909091
#        (18, 80]              NaN  0.880000  0.444444          0.972973
# male   (0, 18]               NaN  0.000000  0.260870          0.800000
#        (18, 80]              0.0  0.098039  0.125000          0.391304
#
# fare
# class              Second     Third
# sex    age
# female (0, 18]   1.000000  0.318182
#        (18, 80]  0.914286  0.391304
# male   (0, 18]   0.818182  0.178571
#        (18, 80]  0.030303  0.192308

# %% [markdown]
# __Additional options__

# %% [markdown]
# full options of pivot_table() method of DataFrame follows:

# %%
# DataFrame.pivot_table(data, values=None, index=None, columns=None,
#                      aggfunc='mean', fill_value=None, margins=False,
#                      dropna=True, margins_name='All')

# %%
titanic.pivot_table(index="embark_town", columns="sex",
                   aggfunc={"survived":sum, "fare": "mean"})
# Out:
#                   fare            survived
# sex             female       male   female male
# embark_town
# Cherbourg    75.169805  48.262109       64   29
# Queenstown   12.634958  13.838922       27    3
# Southampton  38.740929  21.711996      140   77

# %% [markdown]
# - mean fare of female started their journey in Cherbourg was 75.16809
# - sum of survived male who embarked in Queenstown was 3
